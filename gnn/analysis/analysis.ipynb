# %%
import pandas as pd
import numpy as np
df = pd.read_csv("results_nseeds3_nepochs50.csv")

# %%
df.head()
# Out:
#    Unnamed: 0    recall  recall_std      ndcg  ndcg_std  precision  \
# 0           0  0.095766    0.000706  0.156547  0.001700   0.146023
# 1           1  0.022026    0.000858  0.043420  0.001113   0.043832
# 2           2  0.027089    0.001884  0.048464  0.001768   0.048745
# 3           3  0.050185    0.001685  0.078898  0.002996   0.079145
# 4           4  0.093773    0.004026  0.153680  0.006086   0.142382
#
#    precision_std       map   map_std                       modelname
# 0       0.000853  0.037729  0.000614         degree_norm|direct|mean
# 1       0.001381  0.006175  0.000283       degree_norm|direct|concat
# 2       0.000909  0.007536  0.000670     degree_norm|direct|weighted
# 3       0.003409  0.014951  0.000539    degree_norm|direct|attention
# 4       0.005898  0.037763  0.001695  degree_norm|single_linear|mean

# %%
num_models = len(df)
# print(num_models)
results = {}
metric_names = ['recall', 'ndcg', 'precision', 'map']
hparams = [
    ['degree_norm', 'attention'],
    ['direct', 'single_linear', 'multi_linear'],
    ['mean', 'concat', 'weighted', 'attention']
]

hparams_group_names = ['neighbor_aggregator', 'info_updater', 'final_node_repr']
hparams_group_names_lookup = dict(zip(range(len(hparams)), hparams_group_names))

for metric_name in metric_names:
    
    results[metric_name] = {}
    df = df.sort_values(by=[metric_name], ascending=False)
    model_names = df['modelname'].tolist()
    model_names = [name.split('|') for name in model_names]
    model_rankings = list(zip(range(num_models), model_names))
    
    for i, params in enumerate(hparams):
        results[metric_name][hparams_group_names_lookup[i]] = {}
        for p_val in params:
            ranks = np.array([x[0] for x in model_rankings if x[1][i] == p_val])/num_models
            results[metric_name][hparams_group_names_lookup[i]][p_val] = (np.mean(ranks), np.std(ranks))

print('==========')

for metric_name in metric_names:
    print(metric_name)
    for i, hparam_group_name in enumerate(hparams_group_names):
        print(f'  {hparam_group_name}')
        ranks = list(results[metric_name][hparam_group_name].items())
        ranks.sort(key=lambda x:x[1][0])
        for hparam_val, (mean, stddev) in ranks:
            print(f'    {hparam_val}: {mean:.3f} (std {stddev:.3f})')

print('=====mean=====')

for metric_name in metric_names:
#     print(metric_name)
    for i, hparam_group_name in enumerate(hparams_group_names):
#         print(f'  {hparam_group_name}')
        ranks = list(results[metric_name][hparam_group_name].items())
        ranks.sort(key=lambda x:x[1][0])
        for hparam_val, (mean, stddev) in ranks:
            print(f'{mean:.3f}')
            
print('=====stddev=====')
            
for metric_name in metric_names:
#     print(metric_name)
    for i, hparam_group_name in enumerate(hparams_group_names):
#         print(f'  {hparam_group_name}')
        ranks = list(results[metric_name][hparam_group_name].items())
        ranks.sort(key=lambda x:x[1][0])
        for hparam_val, (mean, stddev) in ranks:
            print(f'{stddev:.3f}')
# Out:
# ==========
# recall
#   neighbor_aggregator
#     attention: 0.431 (std 0.294)
#     degree_norm: 0.528 (std 0.274)
#   info_updater
#     single_linear: 0.391 (std 0.221)
#     multi_linear: 0.505 (std 0.216)
#     direct: 0.542 (std 0.376)
#   final_node_repr
#     attention: 0.299 (std 0.263)
#     mean: 0.306 (std 0.186)
#     weighted: 0.514 (std 0.228)
#     concat: 0.799 (std 0.106)
# ndcg
#   neighbor_aggregator
#     attention: 0.413 (std 0.313)
#     degree_norm: 0.545 (std 0.244)
#   info_updater
#     single_linear: 0.396 (std 0.218)
#     multi_linear: 0.500 (std 0.222)
#     direct: 0.542 (std 0.376)
#   final_node_repr
#     attention: 0.271 (std 0.277)
#     mean: 0.312 (std 0.175)
#     weighted: 0.535 (std 0.195)
#     concat: 0.799 (std 0.106)
# precision
#   neighbor_aggregator
#     attention: 0.413 (std 0.312)
#     degree_norm: 0.545 (std 0.246)
#   info_updater
#     single_linear: 0.401 (std 0.223)
#     multi_linear: 0.500 (std 0.213)
#     direct: 0.536 (std 0.380)
#   final_node_repr
#     attention: 0.271 (std 0.277)
#     mean: 0.299 (std 0.169)
#     weighted: 0.549 (std 0.182)
#     concat: 0.799 (std 0.106)
# map
#   neighbor_aggregator
#     attention: 0.417 (std 0.311)
#     degree_norm: 0.542 (std 0.249)
#   info_updater
#     single_linear: 0.391 (std 0.221)
#     multi_linear: 0.500 (std 0.220)
#     direct: 0.547 (std 0.373)
#   final_node_repr
#     mean: 0.292 (std 0.198)
#     attention: 0.292 (std 0.262)
#     weighted: 0.535 (std 0.195)
#     concat: 0.799 (std 0.106)
# =====mean=====
# 0.431
# 0.528
# 0.391
# 0.505
# 0.542
# 0.299
# 0.306
# 0.514
# 0.799
# 0.413
# 0.545
# 0.396
# 0.500
# 0.542
# 0.271
# 0.312
# 0.535
# 0.799
# 0.413
# 0.545
# 0.401
# 0.500
# 0.536
# 0.271
# 0.299
# 0.549
# 0.799
# 0.417
# 0.542
# 0.391
# 0.500
# 0.547
# 0.292
# 0.292
# 0.535
# 0.799
# =====stddev=====
# 0.294
# 0.274
# 0.221
# 0.216
# 0.376
# 0.263
# 0.186
# 0.228
# 0.106
# 0.313
# 0.244
# 0.218
# 0.222
# 0.376
# 0.277
# 0.175
# 0.195
# 0.106
# 0.312
# 0.246
# 0.223
# 0.213
# 0.380
# 0.277
# 0.169
# 0.182
# 0.106
# 0.311
# 0.249
# 0.221
# 0.220
# 0.373
# 0.198
# 0.262
# 0.195
# 0.106
